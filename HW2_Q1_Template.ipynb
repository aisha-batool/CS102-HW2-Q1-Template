# %% [markdown]
# Lets define our functions for MergeSort/QuickSort/Both Algorthims
#
# ---

# %%
# Write your sorting algorithms here
def mergeSort(data):
  pass

def quickSort(data):
  pass

# %% [markdown]
# Lets now evaluate our functions on a range of datasets. *(Sample random output given below shows analysis based on Linear and Binary Search for varying dataset sizes.)*

# %%
'''
Dataset size:  10000
	Linear Search Elapsed Time:  0.8056163787841797  msecs.
	Binary Search Elapsed Time:  0.035762786865234375  msecs.
Dataset size:  20000
	Linear Search Elapsed Time:  1.5213489532470703  msecs.
	Binary Search Elapsed Time:  0.05435943603515625  msecs.
Dataset size:  40000
	Linear Search Elapsed Time:  3.2045841217041016  msecs.
	Binary Search Elapsed Time:  0.08749961853027344  msecs.
Dataset size:  80000
	Linear Search Elapsed Time:  6.356239318847656  msecs.
	Binary Search Elapsed Time:  0.13685226440429688  msecs.
Dataset size:  160000
	Linear Search Elapsed Time:  11.682987213134766  msecs.
	Binary Search Elapsed Time:  0.2148151397705078  msecs.
Dataset size:  320000
	Linear Search Elapsed Time:  26.990890502929688  msecs.
	Binary Search Elapsed Time:  0.3685951232910156  msecs.
Dataset size:  640000
	Linear Search Elapsed Time:  50.68182945251465  msecs.
	Binary Search Elapsed Time:  0.7178783416748047  msecs.
Dataset size:  1280000
	Linear Search Elapsed Time:  107.5899600982666  msecs.
	Binary Search Elapsed Time:  1.3089179992675781  msecs.
Dataset size:  2560000
	Linear Search Elapsed Time:  200.31428337097168  msecs.
	Binary Search Elapsed Time:  3.0210018157958984  msecs.
Dataset size:  5120000
	Linear Search Elapsed Time:  397.1829414367676  msecs.
	Binary Search Elapsed Time:  6.592035293579102  msecs.
  '''

# %% [markdown]
# Lets plot our graph.  *(Sample Graph given below shows analysis based on Linear and Binary Search for varying dataset sizes.)*

# %%
# Use matplotlib to draw the graph.

# %% [markdown]
# ![download (2).png](data:image/png;base64,...)
